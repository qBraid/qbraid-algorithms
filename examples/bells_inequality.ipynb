# %%
import sys
import os

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
from qbraid_algorithms import bells_inequality
import pyqasm

# %%
program = bells_inequality.load_program()

# %%
print(program)
# Out:
# OPENQASM 3.0;
# include "stdgates.inc";
# qubit[2] q0;
# qubit[2] q1;
# qubit[2] q2;
# bit[2] c0;
# bit[2] c1;
# bit[2] c2;
# reset q0;
# reset q1;
# reset q2;
# x q0[0];
# x q0[1];
# h q0[0];
# cx q0[0], q0[1];
# x q1[0];
# x q1[1];
# h q1[0];
# cx q1[0], q1[1];
# x q2[0];
# x q2[1];
# h q2[0];
# cx q2[0], q2[1];
# rx(pi / 3) q0[1];
# rx(2 * pi / 3) q1[1];
# rx(pi / 3) q2[0];
# rx(2 * pi / 3) q2[1];
# c0 = measure q0;
# c1 = measure q1;
# c2 = measure q2;

# %%
pyqasm.draw(program)
